# %% [markdown]
# 之前接触rdbms,动态语言解释器的知识时，涉及到了对表达式（expression）的解析，即将成expression的token解析成相应的ast，很多书籍都介绍了这一种简单却牛逼的解析技术——Pratt Parsing。

# %% [markdown]
# 简单来说，解析的过程如下：
# ![image.png](attachment:image.png)

# %% [markdown]
# 手写Parser，用的最多的技术就是Pratt parsing
