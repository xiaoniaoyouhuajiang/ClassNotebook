# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def binsplit(weight,V):
    """
    返回整数k
    """
    k = 0
    while 2**k*weight <= V:
        k += 1
    return k
    
def completeBag(weights,values,V):
    newweights = []
    newweights = []
    for i in weights:
        binsplit(i,V)
        newweights+[]

# %%
2**3*2
# Out:
# 16
