# %% [markdown]
# # Development Tools
# 基本就是老生常谈的**Debugging， Testing, Mocking, logging, benchmarking, Inspection, code evaluation, tracing, profiling**这几个部分。

# %% [markdown]
# ## Debugging
# 简单来说就是进入到错误的状态，可以查看相应的变量。关于这一块我使用的是Spyder IDE，配合工具自带的variable explorer以及debugger，感觉挺好用的。
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 一个debugger（如py的pdb）的实现逻辑大致是，在断点前加入一个特殊的函数调用，每当解释器执行当前栈时，该调用会复制一个一样的runtime environment，并起一个repl，开发者便能在该repl下查看进程的当前状态。
#
# 其中debugger几个比较重要的方法，包括"next, continue, list"。

# %% [markdown]
# ## Inspection
# PY作为一个动态语言，允许用户修改他的进行时对象的状态，实时检查对象的状态是每个动态语言的基础，Python的标准库inspect有这样的能力。

# %%
import inspect

def inspect_object(o):
    if inspect.isfunction(o) or inspect.ismethod(o):
        print('FUNCTION, arguments:', inspect.signature(o))
    elif inspect.isclass(o):
        print('CLASS, methods:',
             inspect.getmembers(o, inspect.isfunction))
    else:
        print('OBJECT ({}): {}'.format(
            o.__class__,
            [(n, v) for n, v in inspect.getmembers(o)
                if not n.startswith('__')]
        ))
        
class Myclass:
    def __init__(self):
        self.value = 5
        
    def sum_to_value(self, other):
        return self.value + other

# %%
inspect_object(Myclass.sum_to_value)
# Out:
# FUNCTION, arguments: (self, other)

# %%
o = Myclass()
o.value = 10
inspect_object(o)
# Out:
# OBJECT (<class '__main__.Myclass'>): [('sum_to_value', <bound method Myclass.sum_to_value of <__main__.Myclass object at 0x000002268D368E50>>), ('value', 10)]

# %%
inspect_object(Myclass)
# Out:
# CLASS, methods: [('__init__', <function Myclass.__init__ at 0x000001F605632948>), ('sum_to_value', <function Myclass.sum_to_value at 0x000001F605632798>)]

# %% [markdown]
# ## Tracing code
#
# 我要讲解的重头戏内容。
# 为什么要tracing code呢，因为想要traces the execution of a provided function and see the behavior of our software or third-party function。

# %%
import trace
import collections


def report_tracing(func, *args, **kwargs):
    outputs = collections.defaultdict(list)
    
    tracing = trace.Trace(trace=False)
    tracing.runfunc(func, *args, **kwargs)
    
    traced = collections.defaultdict(set)
    for filename, line in tracing.results().counts:
        traced[filename].add(line)
    
    for filename, tracedlines in traced.items():
        with open(filename) as f:
            for idx, fileline in enumerate(f, start=1):
                outputs[filename].append((idx, idx in tracedlines, fileline))

    return outputs

# %%
def print_traced_execution(tracings):
    for filename, tracing in tracings.items():
        print(filename)
        for idx, executed, content in tracing:
            print('{:04d}{} {}'.format(idx, '+' if executed else ' ', content),
                 end='')
        print()

# %%
from tinydb import TinyDB, Query

# %%
print_traced_execution(report_tracing(TinyDB, 'db.json'))
# Out:
# D:\anaconda3\lib\site-packages\tinydb\database.py
# 0001  """
# 0002  This module contains the main component of TinyDB: the database.
# 0003  """
# 0004  from typing import Dict, Iterator, Set
# 0005
# 0006  from . import JSONStorage
# 0007  from .storages import Storage
# 0008  from .table import Table, Document
# 0009
# 0010
# 0011  class TinyDB:
# 0012      """
# 0013      The main class of TinyDB.
# 0014
# 0015      The ``TinyDB`` class is responsible for creating the storage class instance
# 0016      that will store this database's documents, managing the database
# 0017      tables as well as providing access to the default table.
# 0018
# 0019      For table management, a simple ``dict`` is used that stores the table class
# 0020      instances accessible using their table name.
# 0021
# 0022      Default table access is provided by forwarding all unknown method calls
# 0023      and property access operations to the default table by implementing
# 0024      ``__getattr__``.
# 0025
# 0026      When creating a new instance, all arguments and keyword arguments (except
# 0027      for ``storage``) will be passed to the storage class that is provided. If
# 0028      no storage class is specified, :class:`~tinydb.storages.JSONStorage` wil be
# 0029      used.
# 0030
# 0031      .. admonition:: Customization
# 0032
# 0033          For customization, the following class variables can be set:
# 0034
# 0035          - ``table_class`` defines the class that is used to create tables,
# 0036          - ``default_table_name`` defines the name of the default table, and
# 0037          - ``default_storage_class`` will define the class that will be used to
# 0038            create storage instances if no other storage is passed.
# 0039
# 0040          .. versionadded:: 4.0
# 0041
# 0042      .. admonition:: Data Storage Model
# 0043
# 0044          Data is stored using a storage class that provides persistence for a
# 0045          ``dict`` instance. This ``dict`` contains all tables and their data.
# 0046          The data is modelled like this::
# 0047
# 0048              {
# 0049                  'table1': {
# 0050                      0: {document...},
# 0051                      1: {document...},
# 0052                  },
# 0053                  'table2': {
# 0054                      ...
# 0055                  }
# 0056              }
# 0057
# 0058          Each entry in this ``dict`` uses the table name as its key and a
# 0059          ``dict`` of documents as its value. The document ``dict`` contains
# 0060          document IDs as keys and the documents themselves as values.
# 0061
# 0062      :param storage: The class of the storage to use. Will be initialized
# 0063                      with ``args`` and ``kwargs``.
# 0064      """
# 0065
# 0066      #: The class that will be used to create table instances
# 0067      #:
# 0068      #: .. versionadded:: 4.0
# 0069      table_class = Table
# 0070
# 0071      #: The name of the default table
# 0072      #:
# 0073      #: .. versionadded:: 4.0
# 0074      default_table_name = '_default'
# 0075
# 0076      #: The class that will be used by default to create storage instances
# 0077      #:
# 0078      #: .. versionadded:: 4.0
# 0079      default_storage_class = JSONStorage
# 0080
# 0081      def __init__(self, *args, **kwargs):
# 0082          """
# 0083          Create a new instance of TinyDB.
# 0084          """
# 0085
# 0086+         storage = kwargs.pop('storage', self.default_storage_class)
# 0087
# 0088          # Prepare the storage
# 0089+         self._storage = storage(*args, **kwargs)  # type: Storage
# 0090
# 0091+         self._opened = True
# 0092+         self._tables = {}  # type: Dict[str, Table]
# 0093
# 0094      def __repr__(self):
# 0095          args = [
# 0096              'tables={}'.format(list(self.tables())),
# 0097              'tables_count={}'.format(len(self.tables())),
# 0098              'default_table_documents_count={}'.format(self.__len__()),
# 0099              'all_tables_documents_count={}'.format(
# 0100                  ['{}={}'.format(table, len(self.table(table)))
# 0101                   for table in self.tables()]),
# 0102          ]
# 0103
# 0104          return '<{} {}>'.format(type(self).__name__, ', '.join(args))
# 0105
# 0106      def table(self, name: str, **kwargs) -> Table:
# 0107          """
# 0108          Get access to a specific table.
# 0109
# 0110          If the table hasn't been accessed yet, a new table instance will be
# 0111          created using the :attr:`~tinydb.database.TinyDB.table_class` class.
# 0112          Otherwise, the previously created table instance wil be returned.
# 0113
# 0114          All futher options besides the name are passed to the table class which
# 0115          by default is :class:`~tinydb.table.Table`. Check its documentation
# 0116          for further parameters you can pass.
# 0117
# 0118          :param name: The name of the table.
# 0119          :param kwargs: Keyword arguments to pass to the table class constructor
# 0120          """
# 0121
# 0122          if name in self._tables:
# 0123              return self._tables[name]
# 0124
# 0125          table = self.table_class(self.storage, name, **kwargs)
# 0126          self._tables[name] = table
# 0127
# 0128          return table
# 0129
# 0130      def tables(self) -> Set[str]:
# 0131          """
# 0132          Get the names of all tables in the database.
# 0133
# 0134          :returns: a set of table names
# 0135          """
# 0136
# 0137          # TinyDB stores data as a dict of tables like this:
# 0138          #
# 0139          #   {
# 0140          #       '_default': {
# 0141          #           0: {document...},
# 0142          #           1: {document...},
# 0143          #       },
# 0144          #       'table1': {
# 0145          #           ...
# 0146          #       }
# 0147          #   }
# 0148          #
# 0149          # To get a set of table names, we thus construct a set of this main
# 0150          # dict which returns a set of the dict keys which are the table names.
# 0151          #
# 0152          # Storage.read() may return ``None`` if the database file is empty
# 0153          # so we need to consider this case to and return an empty set in this
# 0154          # case.
# 0155
# 0156          return set(self.storage.read() or {})
# 0157
# 0158      def drop_tables(self) -> None:
# 0159          """
# 0160          Drop all tables from the database. **CANNOT BE REVERSED!**
# 0161          """
# 0162
# 0163          # We drop all tables from this database by writing an empty dict
# 0164          # to the storage thereby returning to the initial state with no tables.
# 0165          self.storage.write({})
# 0166
# 0167          # After that we need to remeber to empty the ``_tables`` dict so we'll
# 0168          # create new table instances when a table is accessed again.
# 0169          self._tables.clear()
# 0170
# 0171      def drop_table(self, name: str) -> None:
# 0172          """
# 0173          Drop a specific table from the database. **CANNOT BE REVERSED!**
# 0174
# 0175          :param name: The name of the table to drop.
# 0176          """
# 0177
# 0178          # If the table is currently opened, we need to forget the table class
# 0179          # instance
# 0180          if name in self._tables:
# 0181              del self._tables[name]
# 0182
# 0183          data = self.storage.read()
# 0184
# 0185          # The database is uninitialized, there's nothing to do
# 0186          if data is None:
# 0187              return
# 0188
# 0189          # The table does not exist, there's nothing to do
# 0190          if name not in data:
# 0191              return
# 0192
# 0193          # Remove the table from the data dict
# 0194          del data[name]
# 0195
# 0196          # Store the updated data back to the storage
# 0197          self.storage.write(data)
# 0198
# 0199      @property
# 0200      def storage(self) -> Storage:
# 0201          """
# 0202          Get the storage instance used for this TinyDB instance.
# 0203
# 0204          :return: This instance's storage
# 0205          :rtype: Storage
# 0206          """
# 0207          return self._storage
# 0208
# 0209      def close(self) -> None:
# 0210          """
# 0211          Close the database.
# 0212
# 0213          This may be needed if the storage instance used for this database
# 0214          needs to perform cleanup operations like closing file handles.
# 0215
# 0216          To ensure this method is called, the TinyDB instance can be used as a
# 0217          context manager::
# 0218
# 0219              with TinyDB('data.json') as db:
# 0220                  db.insert({'foo': 'bar'})
# 0221
# 0222          Upon leaving this context, the ``close`` method will be called.
# 0223          """
# 0224          self._opened = False
# 0225          self.storage.close()
# 0226
# 0227      def __enter__(self):
# 0228          """
# 0229          Use the database as a context manager.
# 0230
# 0231          Using the database as a context manager ensures that the
# 0232          :meth:`~tinydb.database.TinyDB.close` method is called upon leaving
# 0233          the context.
# 0234
# 0235          :return: The current instance
# 0236          """
# 0237          return self
# 0238
# 0239      def __exit__(self, *args):
# 0240          """
# 0241          Close the storage instance when leaving a context.
# 0242          """
# 0243          if self._opened:
# 0244              self.close()
# 0245
# 0246      def __getattr__(self, name):
# 0247          """
# 0248          Forward all unknown attribute calls to the default table instance.
# 0249          """
# 0250          return getattr(self.table(self.default_table_name), name)
# 0251
# 0252      # Here we forward magic methods to the default table instance. These are
# 0253      # not handled by __getattr__ so we need to forward them manually here
# 0254
# 0255      def __len__(self):
# 0256          """
# 0257          Get the total number of documents in the default table.
# 0258
# 0259          >>> db = TinyDB('db.json')
# 0260          >>> len(db)
# 0261          0
# 0262          """
# 0263          return len(self.table(self.default_table_name))
# 0264
# 0265      def __iter__(self) -> Iterator[Document]:
# 0266          """
# 0267          Return an iterater for the default table's documents.
# 0268          """
# 0269          return iter(self.table(self.default_table_name))
#
# D:\anaconda3\lib\site-packages\tinydb\storages.py
# 0001  """
# 0002  Contains the :class:`base class <tinydb.storages.Storage>` for storages and
# 0003  implementations.
# 0004  """
# 0005
# 0006  import io
# 0007  import json
# 0008  import os
# 0009  from abc import ABC, abstractmethod
# 0010  from typing import Dict, Any, Optional
# 0011
# 0012  __all__ = ('Storage', 'JSONStorage', 'MemoryStorage')
# 0013
# 0014
# 0015  def touch(path: str, create_dirs: bool):
# 0016      """
# 0017      Create a file if it doesn't exist yet.
# 0018
# 0019      :param path: The file to create.
# 0020      :param create_dirs: Whether to create all missing parent directories.
# 0021      """
# 0022+     if create_dirs:
# 0023          base_dir = os.path.dirname(path)
# 0024
# 0025          # Check if we need to create missing parent directories
# 0026          if not os.path.exists(base_dir):
# 0027              os.makedirs(base_dir)
# 0028
# 0029      # Create the file by opening it in 'a' mode which creates the file if it
# 0030      # does not exist yet but does not modify its contents
# 0031+     with open(path, 'a'):
# 0032+         pass
# 0033
# 0034
# 0035  class Storage(ABC):
# 0036      """
# 0037      The abstract base class for all Storages.
# 0038
# 0039      A Storage (de)serializes the current state of the database and stores it in
# 0040      some place (memory, file on disk, ...).
# 0041      """
# 0042
# 0043      # Using ABCMeta as metaclass allows instantiating only storages that have
# 0044      # implemented read and write
# 0045
# 0046      @abstractmethod
# 0047      def read(self) -> Optional[Dict[str, Dict[str, Any]]]:
# 0048          """
# 0049          Read the current state.
# 0050
# 0051          Any kind of deserialization should go here.
# 0052
# 0053          Return ``None`` here to indicate that the storage is empty.
# 0054          """
# 0055
# 0056          raise NotImplementedError('To be overridden!')
# 0057
# 0058      @abstractmethod
# 0059      def write(self, data: Dict[str, Dict[str, Any]]) -> None:
# 0060          """
# 0061          Write the current state of the database to the storage.
# 0062
# 0063          Any kind of serialization should go here.
# 0064
# 0065          :param data: The current state of the database.
# 0066          """
# 0067
# 0068          raise NotImplementedError('To be overridden!')
# 0069
# 0070      def close(self) -> None:
# 0071          """
# 0072          Optional: Close open file handles, etc.
# 0073          """
# 0074
# 0075          pass
# 0076
# 0077
# 0078  class JSONStorage(Storage):
# 0079      """
# 0080      Store the data in a JSON file.
# 0081      """
# 0082
# 0083      def __init__(self, path: str, create_dirs=False, encoding=None, access_mode='r+', **kwargs):
# 0084          """
# 0085          Create a new instance.
# 0086
# 0087          Also creates the storage file, if it doesn't exist and the access mode is appropriate for writing.
# 0088
# 0089          :param path: Where to store the JSON data.
# 0090          :param access_mode: mode in which the file is opened (r, r+, w, a, x, b, t, +, U)
# 0091          :type access_mode: str
# 0092          """
# 0093
# 0094+         super().__init__()
# 0095
# 0096+         self._mode = access_mode
# 0097+         self.kwargs = kwargs
# 0098
# 0099          # Create the file if it doesn't exist and creating is allowed by the
# 0100          # access mode
# 0101+         if any([character in self._mode for character in ('+', 'w', 'a')]):  # any of the writing modes
# 0102+             touch(path, create_dirs=create_dirs)
# 0103
# 0104          # Open the file for reading/writing
# 0105+         self._handle = open(path, mode=self._mode, encoding=encoding)
# 0106
# 0107      def close(self) -> None:
# 0108          self._handle.close()
# 0109
# 0110      def read(self) -> Optional[Dict[str, Dict[str, Any]]]:
# 0111          # Get the file size by moving the cursor to the file end and reading
# 0112          # its location
# 0113          self._handle.seek(0, os.SEEK_END)
# 0114          size = self._handle.tell()
# 0115
# 0116          if not size:
# 0117              # File is empty so we return ``None`` so TinyDB can properly
# 0118              # initialize the database
# 0119              return None
# 0120          else:
# 0121              # Return the cursor to the beginning of the file
# 0122              self._handle.seek(0)
# 0123
# 0124              # Load the JSON contents of the file
# 0125              return json.load(self._handle)
# 0126
# 0127      def write(self, data: Dict[str, Dict[str, Any]]):
# 0128          # Move the cursor to the beginning of the file just in case
# 0129          self._handle.seek(0)
# 0130
# 0131          # Serialize the database state using the user-provided arguments
# 0132          serialized = json.dumps(data, **self.kwargs)
# 0133
# 0134          # Write the serialized data to the file
# 0135          try:
# 0136              self._handle.write(serialized)
# 0137          except io.UnsupportedOperation:
# 0138              raise IOError('Cannot write to the database. Access mode is "{0}"'.format(self._mode))
# 0139
# 0140          # Ensure the file has been writtens
# 0141          self._handle.flush()
# 0142          os.fsync(self._handle.fileno())
# 0143
# 0144          # Remove data that is behind the new cursor in case the file has
# 0145          # gotten shorter
# 0146          self._handle.truncate()
# 0147
# 0148
# 0149  class MemoryStorage(Storage):
# 0150      """
# 0151      Store the data as JSON in memory.
# 0152      """
# 0153
# 0154      def __init__(self):
# 0155          """
# 0156          Create a new instance.
# 0157          """
# 0158
# 0159          super().__init__()
# 0160          self.memory = None
# 0161
# 0162      def read(self) -> Optional[Dict[str, Dict[str, Any]]]:
# 0163          return self.memory
# 0164
# 0165      def write(self, data: Dict[str, Dict[str, Any]]):
# 0166          self.memory = data
#
# D:\anaconda3\lib\_bootlocale.py
# 0001  """A minimal subset of the locale module used at interpreter startup
# 0002  (imported by the _io module), in order to reduce startup time.
# 0003
# 0004  Don't import directly from third-party code; use the `locale` module instead!
# 0005  """
# 0006
# 0007  import sys
# 0008  import _locale
# 0009
# 0010  if sys.platform.startswith("win"):
# 0011      def getpreferredencoding(do_setlocale=True):
# 0012+         if sys.flags.utf8_mode:
# 0013              return 'UTF-8'
# 0014+         return _locale._getdefaultlocale()[1]
# 0015  else:
# 0016      try:
# 0017          _locale.CODESET
# 0018      except AttributeError:
# 0019          if hasattr(sys, 'getandroidapilevel'):
# 0020              # On Android langinfo.h and CODESET are missing, and UTF-8 is
# 0021              # always used in mbstowcs() and wcstombs().
# 0022              def getpreferredencoding(do_setlocale=True):
# 0023                  return 'UTF-8'
# 0024          else:
# 0025              def getpreferredencoding(do_setlocale=True):
# 0026                  if sys.flags.utf8_mode:
# 0027                      return 'UTF-8'
# 0028                  # This path for legacy systems needs the more complex
# 0029                  # getdefaultlocale() function, import the full locale module.
# 0030                  import locale
# 0031                  return locale.getpreferredencoding(do_setlocale)
# 0032      else:
# 0033          def getpreferredencoding(do_setlocale=True):
# 0034              assert not do_setlocale
# 0035              if sys.flags.utf8_mode:
# 0036                  return 'UTF-8'
# 0037              result = _locale.nl_langinfo(_locale.CODESET)
# 0038              if not result and sys.platform == 'darwin':
# 0039                  # nl_langinfo can return an empty string
# 0040                  # when the setting has an invalid value.
# 0041                  # Default to UTF-8 in that case because
# 0042                  # UTF-8 is the default charset on OSX and
# 0043                  # returning nothing will crash the
# 0044                  # interpreter.
# 0045                  result = 'UTF-8'
# 0046              return result

# %% [markdown]
# **问题：为什么调用需要用栈来存储？**

# %% [markdown]
# 栈简单来说就是后入先出呗，注意，这里所说的函数调用的存储数据结构指的是局部状态的存储结构。看：
#
# ```c
# int main() {
#   a();
#   return 0;
# }
#
# void a() {
#   b();
# }
#
# void b() {
#   c();
# }
#
# void c() {
# }
# ```
#
# 表示一下调用以及返回完成的整个流程
# ```shell
# main()  a()  b()  c()
#    -                         main()
#    |
#    +>     -                    a()
#    .      |
#    .      +>   -                 b()
#    .      .    |
#    .      .    +>   -              c()
#    .      .    .    |
#    .      .    +   <-              return from c()
#    .      .    |
#    .      +   <-                 return from b()
#    .      |
#    +     <-                    return from a()
#    |
#    -                         return from main()
#
# ```
#
# 看到调用者总体比被调用者长寿，其实就是模拟一个嵌套关系，(进入，)出栈。

# %% [markdown]
# **这样去看好像还不是对使用者特别友好，怎么办？**

# %% [markdown]
# 试试以下几种办法：
# * python hunter
# * viztracer
# * livepython
# * debugger（最细致的排查）
# * cyberbrain
# * 自己写

# %% [markdown]
# * python hunter
# ![image.png](attachment:image.png)

# %% [markdown]
# * viztracer
# ![image.png](attachment:image.png)

# %% [markdown]
# * livepython
# ![image.png](attachment:image.png)

# %% [markdown]
# * codimension
# ![image.png](attachment:image.png)
